# %%
import pandas as pd
  
esg_df = pd.DataFrame(pd.read_excel("ESG_df.xlsx"))
news_df = pd.DataFrame(pd.read_excel("news_sentiment_df.xlsx"))
returns_df = pd.DataFrame(pd.read_excel("returns_df_GG.xlsx"))

# %%
new_date = returns_df["Date"]
new_date_new = []
for i in new_date:
    new_date_new.append(i)
    new_date_new.append(i)
    new_date_new.append(i)
new_date_hi = pd.Series(new_date_new)

#esg_df["Date"] = new_date[::3]

n = 87
esg_df_hi = pd.concat([esg_df] * n)
esg_df_hi.reset_index(inplace=True, drop=True)
#esg_df_hi["Type"]
esg_df_hi["Date"] = new_date_hi
#esg_df_hi["Date"].fillna(new_date, inplace=True)
#esg_df_hi["Date"] = new_date
#esg_df_hi.set_index(['Type'], inplace=True)
#esg_df_hi.drop(['Date'], axis=1, inplace=True)
#esg_df_hi["Date1"] = new_date[::3]
#esg_df_hi["Date"].fillna(new_date, inplace=True)
#new_date_hi = pd.Series(new_date_new)
#new_date_hi
esg_df_hi
# Out:
#            Date              Type     A    AAL   AAP   ABBV   ABC    ABT  \
# 0    2020-09-25       socialScore  9.44  12.65  9.14  16.64  6.35  13.54
# 1    2020-09-25   governanceScore  6.26   5.40  3.33  10.10  5.80   9.39
# 2    2020-09-25  environmentScore  0.87  11.76  0.10   0.65  0.84   3.03
# 3    2020-09-28       socialScore  9.44  12.65  9.14  16.64  6.35  13.54
# 4    2020-09-28   governanceScore  6.26   5.40  3.33  10.10  5.80   9.39
# ..          ...               ...   ...    ...   ...    ...   ...    ...
# 256  2021-01-28   governanceScore  6.26   5.40  3.33  10.10  5.80   9.39
# 257  2021-01-28  environmentScore  0.87  11.76  0.10   0.65  0.84   3.03
# 258  2021-01-29       socialScore  9.44  12.65  9.14  16.64  6.35  13.54
# 259  2021-01-29   governanceScore  6.26   5.40  3.33  10.10  5.80   9.39
# 260  2021-01-29  environmentScore  0.87  11.76  0.10   0.65  0.84   3.03
#
#       ACN  ADBE  ...    WY   WYNN    XEL  XLNX    XOM   XRAY   XYL    YUM  \
# ...

# %%
news_df
#returns_df.append(news_df)
dfs = [returns_df, news_df, esg_df_hi]
for df in dfs:
    df = df.set_index(['Date', 'Type'], inplace=True)

# %%
returns_df
# Out:
#                           A       AAL       AAP      ABBV       ABC      ABMD  \
# Date       Type
# 2020-09-25 Return  0.014013  0.044180  0.018404  0.003725  0.022607  0.015126
# 2020-09-28 Return  0.018630  0.038242  0.026638  0.012177  0.008058  0.026685
# 2020-09-29 Return  0.007135 -0.039969 -0.010952 -0.004468 -0.014552 -0.003985
# 2020-09-30 Return  0.007184  0.003265  0.011799  0.008056  0.007903  0.016883
# 2020-10-01 Return  0.002774  0.023596  0.008795 -0.005138 -0.016096 -0.059951
# ...                     ...       ...       ...       ...       ...       ...
# 2021-10-05 Return  0.004397  0.003740  0.008930  0.007174  0.002366  0.059260
# 2021-10-06 Return  0.004051 -0.043316  0.010908 -0.001735 -0.014417  0.014528
# 2021-10-07 Return  0.010869 -0.018014  0.015144  0.014179  0.014286  0.008894
# 2021-10-08 Return -0.018349 -0.004958 -0.001632  0.002796  0.006747 -0.009315
# 2021-10-11 Return -0.014888  0.007972 -0.005930 -0.005936  0.024964 -0.011984
#
# ...

# %%
news_df
# Out:
#                               A      AAL     AAP      ABBV  ABC  ABMD     ABT  \
# Date       Type
# 2019-10-28 sentiment score  0.0  0.00000  0.0000  0.000000  0.0   0.0  0.0000
# 2019-10-30 sentiment score  0.0  0.00000  0.0000  0.000000  0.0   0.0  0.0000
# 2019-11-01 sentiment score  0.0  0.00000  0.0000  0.000000  0.0   0.0  0.0000
# 2019-11-11 sentiment score  0.0  0.00000  0.0000  0.000000  0.0   0.0  0.0000
# 2019-11-12 sentiment score  0.0  0.00000  0.0000  0.000000  0.0   0.0  0.0000
# ...                         ...      ...     ...       ...  ...   ...     ...
# 2021-10-07 sentiment score  0.0 -0.00235  0.0000  0.141243  0.0   0.0  0.3400
# 2021-10-08 sentiment score  0.0  0.00000 -0.6908  0.636900  0.0   0.0  0.6369
# 2021-10-09 sentiment score  0.0  0.00000  0.0000  0.000000  0.0   0.0  0.0000
# 2021-10-10 sentiment score  0.0  0.00000  0.0000  0.000000  0.0   0.0  0.0000
# 2021-10-11 sentiment score  0.0  0.22020  0.0000  0.111500  0.0   0.0  0.0000
#
# ...

# %%
hi = news_df.combine_first(returns_df)
new_done = hi.combine_first(esg_df_hi)
#hi.dtypes
new_done.tail(200)
# Out:
#                                    A       AAL       AAP      ABBV       ABC  \
# Date       Type
# 2021-06-16 Return          -0.007122  0.001755 -0.018639 -0.002590 -0.005629
#            sentiment score  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-06-17 Return           0.023191 -0.026281 -0.007809 -0.005453 -0.002112
#            sentiment score  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-06-18 Return          -0.013000  0.002699 -0.005453 -0.015492 -0.031242
# ...                              ...       ...       ...       ...       ...
# 2021-10-08 sentiment score  0.000000  0.000000 -0.690800  0.636900  0.000000
# 2021-10-09 sentiment score  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-10-10 sentiment score  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-10-11 Return          -0.014888  0.007972 -0.005930 -0.005936  0.024964
#            sentiment score  0.000000  0.220200  0.000000  0.111500  0.000000
#
# ...

# %%
new_done.to_csv("final_data.csv")
